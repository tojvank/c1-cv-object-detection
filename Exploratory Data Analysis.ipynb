# %% [markdown]
# # Explore the dataset
#
#
# In this notebook, we will perform an EDA (Exploratory Data Analysis) on the processed Waymo dataset (data in the `processed` folder). In the first part, you will create a function to display

# %%
from utils import get_dataset
#import glob
import matplotlib
import matplotlib.pyplot as plt
#import matplotlib.patches as patches
import numpy as np
import tensorflow as tf

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from utils import get_dataset
#       2 #import glob
#       3 import matplotlib
#
# File ~\CLionProjects\c1-cv-object-detection\utils.py:4, in <module>
#       1 import logging
#       3 import tensorflow.compat.v1 as tf
# ----> 4 from object_detection.inputs import train_input
#       5 from object_detection.protos import input_reader_pb2
#       6 from object_detection.builders.dataset_builder import build as build_dataset
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\object_detection\inputs.py:24, in <module>
#      21 import functools
#      23 import tensorflow as tf
# ---> 24 from object_detection.builders import dataset_builder
#      25 from object_detection.builders import image_resizer_builder
# ...

# %%
#data = get_dataset("./data/waymo/training_and_validation/*.tfrecord")
#data
dataset = get_dataset("/home/workspace/data/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord")

# %%
data="/home/workspace/data/train/*.tfrecord"
data2=get_dataset(data)
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/home/workspace/data/train/*.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/workspace/data/train/*.tfrecord']
# INFO:tensorflow:Number of filenames to read: 86

# %% [markdown]
# ## Write a function to display an image and the bounding boxes
#
# Implement the `display_images` function below. This function takes a batch as an input and display an image with its corresponding bounding boxes. The only requirement is that the classes should be color coded (eg, vehicles in red, pedestrians in blue, cyclist in green).

# %%
def display_images(batch):
    # TODO - Your implementation here
    colors={
        1:"green",
        2:"red",
        3:"blue"
    }
    
    fig, ax = plt.subplots(figsize=(7,7))
    a,b,c = batch["image"].shape
    print(a,b,c)
    ax.imshow(batch["image"].numpy().astype("uint8"))
    gtruth = batch["groundtruth_classes"].numpy()
    
    for i in range(len(batch["groundtruth_boxes"])):
        miny, minx, maxy, maxx = batch["groundtruth_boxes"][i]
        groundc=gtruth[i]
        
        rett = matplotlib.patches.Rectangle((minx*a, miny*b), (maxx-minx)*a, (maxy-miny)*b, edgecolor=colors[groundc],
                                           facecolor="none")
        
        ax.add_patch(rett)
    plt.show()

# %% [markdown]
# ## Display 10 images
#
# Using the dataset created in the second cell and the function you just coded, display 10 random images with the associated bounding boxes. You can use the methods `take` and `shuffle` on the dataset.

# %%
# Display 10 random images in dataset
for batch in data2.take(10):
    display_images(batch)
# Out:
# 640 640 3
# 640 640 3
# 640 640 3
# 640 640 3
# 640 640 3
# 640 640 3
# 640 640 3
# 640 640 3
# 640 640 3
# 640 640 3

# %% [markdown]
# ## Additional EDA
#
# In this last part, you are free to perform any additional analysis of the dataset. What else would like to know about the data?
# For example, think about data distribution. So far, you have only looked at a single file...

# %%
label = {1: 0, 2:0,4:0}
dict_labels = {1:[], 2:[], 4:[]}
for batch in dataset.take(150):
    count = {1: 0, 2:0,4:0}
    classes = batch['groundtruth_classes'].numpy()
    for i in classes:
        label[i]+= 1
        count[i]+=1
        dict_labels[i].append(count[i])

# %%
label
# Out:
# {1: 2092, 2: 206, 4: 0}

# %% [markdown]
# To see what kind of class we have in majority

# %%
class_name = ['cyclist', 'pedestrian', 'vehicle']
plt.bar(class_name, count.values(), color=['red', 'blue', 'green'])
plt.ylabel('Detected objects')
plt.title('Distribution of the classes')
# Out:
# Text(0.5, 1.0, 'Distribution of the classes')
